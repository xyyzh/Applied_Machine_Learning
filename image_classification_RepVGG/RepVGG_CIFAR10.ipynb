# %%
# !git clone https://github.com/xyyzh/RepVGG.git
# Out:
# Cloning into 'RepVGG'...
# remote: Enumerating objects: 545, done.
# remote: Counting objects: 100% (293/293), done.
# remote: Compressing objects: 100% (245/245), done.
# remote: Total 545 (delta 187), reused 105 (delta 48), pack-reused 252
# Receiving objects: 100% (545/545), 446.26 KiB | 733.00 KiB/s, done.
# Resolving deltas: 100% (334/334), done.

# %% [markdown]
# #CIFAR10

# %% [markdown]
# ##RepVGG-A0

# %% [markdown]
# ###epochs=30
# not fully converged.
# val acc: 66.5999984741211,
# test acc: 65.680

# %%
# !python RepVGG/train_CIFAR10.py -a RepVGG-A0 --dist-url 'tcp://127.0.0.1:23333' --dist-backend 'nccl' --multiprocessing-distributed --world-size 1 --rank 0 --tag hello --custwd --wd 4e-5
# Out:
# Traceback (most recent call last):
#   File "RepVGG/train_CIFAR10.py", line 16, in <module>
#     import torch
#   File "/usr/local/lib/python3.7/dist-packages/torch/__init__.py", line 197, in <module>
#     from torch._C import *  # noqa: F403
# RuntimeError: KeyboardInterrupt:

# %%
# !python RepVGG/test_CIFAR10.py train RepVGG-A0_hello_best.pth.tar -a RepVGG-A0
# Out:
# RepVGG Block, identity =  None
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %% [markdown]
# ###epochs=100

# %%
# !python RepVGG/train_CIFAR10.py 10 -a RepVGG-A0 --dist-url 'tcp://127.0.0.1:23333' --dist-backend 'nccl' --multiprocessing-distributed --world-size 1 --rank 0 --tag hello --custwd --wd 4e-5
# Out:
# start
# Use GPU: 0 for training
# RepVGG Block, identity =  None
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
# !python RepVGG/test_CIFAR10.py train RepVGG-A0_hello_best.pth.tar 10 -a RepVGG-A0
# Out:
# RepVGG Block, identity =  None
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %% [markdown]
# ##RepVGG-B2
# epochs=100

# %%
# !python RepVGG/train_CIFAR10.py 10 -a RepVGG-B2 --dist-url 'tcp://127.0.0.1:23333' --dist-backend 'nccl' --multiprocessing-distributed --world-size 1 --rank 0 --tag hello --custwd --wd 4e-5
# Out:
# start
# Use GPU: 0 for training
# RepVGG Block, identity =  None
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
# !python RepVGG/test_CIFAR10.py train RepVGG-B2_hello_best.pth.tar 10 -a RepVGG-B2
# Out:
# RepVGG Block, identity =  None
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %% [markdown]
# #other

# %% [markdown]
# ##CIFAR100

# %% [markdown]
# ###RepVGG-A0

# %%
# !python RepVGG/train_CIFAR100.py 100 -a RepVGG-A0 --dist-url 'tcp://127.0.0.1:23333' --dist-backend 'nccl' --multiprocessing-distributed --world-size 1 --rank 0 --tag cifar100 --custwd --wd 4e-5
# Out:
# Use GPU: 0 for training
# RepVGG Block, identity =  None
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
# !python RepVGG/test_CIFAR100.py train RepVGG-A0_cifar100_best.pth.tar 100 -a RepVGG-A0
# Out:
# RepVGG Block, identity =  None
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %% [markdown]
# ###RepVGG-B2

# %%
# !python RepVGG/train_CIFAR100.py 100 -a RepVGG-B2 --dist-url 'tcp://127.0.0.1:23333' --dist-backend 'nccl' --multiprocessing-distributed --world-size 1 --rank 0 --tag hello --custwd --wd 4e-5
# Out:
# Use GPU: 0 for training
# RepVGG Block, identity =  None
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
# !python RepVGG/test_CIFAR100.py train RepVGG-B2_hello_best.pth.tar 100 -a RepVGG-B2
# Out:
# RepVGG Block, identity =  None
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...
